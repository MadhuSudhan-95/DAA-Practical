# %%
#Linear
import time

arr = list(map(int, input("Enter elements: ").split()))
key = int(input("Enter number to search: "))

start = time.time()

for i in range(len(arr)):
    if arr[i] == key:
        print("Found at index", i)
        break
else:
    print("Not Found")

end = time.time()

print("Execution Time:", end - start, "seconds")
print("Time Complexity: O(n)")
# Out:
# Enter elements: 5 1 6 9 2
# Enter number to search: 6
# Found at index 2
# Execution Time: 0.00024318695068359375 seconds
# Time Complexity: O(n)

# %%
#Binary
import time

arr = list(map(int, input("Enter elements: ").split()))
arr.sort()
print("Sorted Array:", arr)
key = int(input("Enter number to search: "))

start = time.time()

low, high = 0, len(arr) - 1

while low <= high:
    mid = (low + high) // 2

    if arr[mid] == key:
        print("Found at index", mid)
        break
    elif arr[mid] < key:
        low = mid + 1
    else:
        high = mid - 1
else:
    print("Not Found")

end = time.time()
print("Execution Time:", end - start, "seconds")
print("Time Complexity: O(log n)")
# Out:
# Enter elements:  1 5 4 2
# Sorted Array: [1, 2, 4, 5]
# Enter number to search: 5
# Found at index 3
# Execution Time: 0.000335693359375 seconds
# Time Complexity: O(log n)
